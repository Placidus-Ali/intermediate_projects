# %% [markdown]
# Match Details: You can analyze the match details such as the date and time of the match, the stage of the tournament, the stadium, and the city where the match was played. This can provide insights into the scheduling and logistics of the matches.
#
# Goal Statistics: You can examine the number of goals scored by the home team and the away team in each match. This information can be used to analyze the goal-scoring prowess of teams or compare the offensive and defensive strengths of teams.
#
# Attendance: The dataset provides information on the attendance of each match. You can analyze the attendance numbers to understand the popularity and interest in different matches or stages of the tournament.
#
#
#
# World Cup Winners: You can identify the winners of each World Cup edition from the "Winner" column. This information can be used to analyze the historical success of different countries in the tournament.
#
# Runners-Up and Third Place: The dataset includes columns for the runners-up and third-place teams for each World Cup. You can analyze the performance of these teams and identify recurring strong competitors.
#
# Goals Scored: The dataset provides the total number of goals scored in each World Cup. Analyzing this information can give insights into the overall level of competitiveness and offensive play in different editions of the tournament.
#
# Attendance: The dataset includes information on the attendance of each World Cup. You can analyze the attendance numbers to understand the popularity and growth of the tournament over time.
#
# Qualified Teams and Matches Played: The dataset provides information on the number of qualified teams and matches played in each World Cup. This can be used to analyze the expansion or contraction of the tournament and its format changes over the years.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:/Users/STUTERN/Downloads/FIFA_World_Cup_Dataset/WorldCupMatches.csv")
df2 = pd.read_csv("C:/Users/STUTERN/Downloads/FIFA_World_Cup_Dataset/WorldCups.csv")

# %%
df1
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
df2
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

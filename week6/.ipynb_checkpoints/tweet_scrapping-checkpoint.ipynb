# %% [markdown]
# #### In this assignment, I'm going to extract data from twitter on the 3 presidential candidates (Peter Obi, Tinubu and Atiku), using their names as search string. With the aim of checking the candidate with the most polarity (positive tweets) between Jan 1st, 2022 to Nov 8th, 2022.

# %%
#!pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
# pip install textblob

# %%
pip install nest-asyncio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (1.5.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import twint
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import re
import glob
import os
from datetime import datetime
from textblob import TextBlob
from nltk.tokenize import WordPunctTokenizer
from nltk.corpus import stopwords
from sqlalchemy import create_engine


import nest_asyncio
nest_asyncio.apply() # I used this nest_asyncio to resolve this error "This event loop is already running"

# %%
# creating a search string 
candidates={"Bola Ahmed Tinubu": "Asiwaju\Tinubu\Jagaban", 
           "Peter Obi": "PO\Peter Obi\ObiDatti", 
           "Atiku": "Atiku"}

# %%
def twintConfig(search_string):
    c = twint.Config()
    c.Search = search_string[1]
    c.Limit=500
    c.Lang = 'en'
    c.Pandas = True
    c.Pandas_au = True          
    c.Pandas_clean=True
    c.Since='2022-01-01'
    c.Until='2022-11-08'
    twint.run.Search(c)

# %%
def Run_Twint(search_vals):
    
    #set empty dataframe for join
    out_df= pd.DataFrame()
    
    for candidates in search_vals.items():
        print ("running for search item: "+candidates[0]+"\n")
        print ("Search string: "+candidates[1]+"\n")
        
        #run twint
        twintConfig(candidates)
        
        #get dataframe
        candidates_2023 = twint.storage.panda.Tweets_df
        
        #join Dataframes and create 'candidates' column
        candidates_2023["candidates"]= candidates[0]
        out_df = pd.concat([out_df,candidates_2023])
        
    return out_df

# %%
# Extracting the tweets of the candidates from Jan 1st, 2022 till Nov 8th, 2022.
# candidates_2023 = Run_Twint(candidates)

# %%
candidates_2023
# Out:
#                       id      conversation_id    created_at  \
# 0    1589764392199294977  1589490200282923008  1.667864e+12
# 1    1589762989334618112  1589702301509648384  1.667864e+12
# 2    1589759942428602369  1589759942428602369  1.667863e+12
# 3    1589759791446241280  1589699071740383233  1.667863e+12
# 4    1589743505274204160  1589743505274204160  1.667859e+12
# ..                   ...                  ...           ...
# 511  1589750539113619456  1589562806680317954  1.667861e+12
# 512  1589750472373477376  1589750472373477376  1.667861e+12
# 513  1589750453444972545  1589690734667796480  1.667861e+12
# 514  1589750442850152448  1589719170567966721  1.667861e+12
# 515  1589750401091637248  1589721056977518592  1.667861e+12
#
#                     date timezone place  \
# 0    2022-11-08 00:39:02    +0100
# 1    2022-11-08 00:33:27    +0100
# 2    2022-11-08 00:21:21    +0100
# 3    2022-11-08 00:20:45    +0100
# 4    2022-11-07 23:16:02    +0100
# ..                   ...      ...   ...
# 511  2022-11-07 23:43:59    +0100
# 512  2022-11-07 23:43:43    +0100
# 513  2022-11-07 23:43:38    +0100
# 514  2022-11-07 23:43:36    +0100
# 515  2022-11-07 23:43:26    +0100
#
#                                                  tweet language hashtags  \
# 0    @firstladyship Stop worrying yourself over our...       en       []
# 1    @neckobi What's this one tweeting? Deep inside...       en       []
# 2    @officialABAT @ABATMediaCentre @Progressive4BA...       in       []
# 3    @AjuriNgelale This man is too good.  Tinubu-Sh...       en       []
# 4    Asiwaju Bola Ahmed Tinubu, APC Presidential ca...       en       []
# ..                                                 ...      ...      ...
# 511  @DEferode @Nkemchor_ @_dinomelaye @OfficialPDP...       en       []
# 512  @_dinomelaye see your disgraceful self. If dem...       en       []
# 513  @Maxajee @KwankwasoRM How did know this? i kno...       en       []
# 514  @akingbade_yinka @OneDayEgoBetter @Pres_Adebay...       en       []
# 515  @Sidi_Araphat @Fulani_Tutor @IAOkowa @LailaAti...       en       []
#
#     cashtags  ...  source user_rt_id user_rt retweet_id  \
# 0         []  ...
# 1         []  ...
# 2         []  ...
# 3         []  ...
# 4         []  ...
# ..       ...  ...     ...        ...     ...        ...
# 511       []  ...
# 512       []  ...
# 513       []  ...
# 514       []  ...
# 515       []  ...
#
#                                               reply_to retweet_date translate  \
# 0    [{'screen_name': 'firstladyship', 'name': 'NEF...
# 1    [{'screen_name': 'neckobi', 'name': 'Nonso Obi...
# 2                                                   []
# 3    [{'screen_name': 'AjuriNgelale', 'name': 'Ajur...
# 4                                                   []
# ..                                                 ...          ...       ...
# 511  [{'screen_name': 'DEferode', 'name': 'David Ef...
# 512                                                 []
# 513  [{'screen_name': 'Maxajee', 'name': 'YaYa Abba...
# 514  [{'screen_name': 'akingbade_yinka', 'name': 'O...
# 515  [{'screen_name': 'Sidi_Araphat', 'name': 'Sidi...
#
#     trans_src trans_dest         candidates
# 0                         Bola Ahmed Tinubu
# 1                         Bola Ahmed Tinubu
# 2                         Bola Ahmed Tinubu
# 3                         Bola Ahmed Tinubu
# 4                         Bola Ahmed Tinubu
# ..        ...        ...                ...
# 511                                   Atiku
# 512                                   Atiku
# 513                                   Atiku
# 514                                   Atiku
# 515                                   Atiku
#
# [699 rows x 39 columns]

# %%
pd.set_option('display.max_columns', None) # used to display all the columns without hidding any

# %%
# checking the columns in the dataset
candidates_2023.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest', 'candidates'],
#       dtype='object')

# %%
candidates_2023.shape
# Out:
# (699, 39)

# %%
candidates_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 515
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               699 non-null    object
#  1   conversation_id  699 non-null    object
#  2   created_at       699 non-null    float64
#  3   date             699 non-null    object
#  4   timezone         699 non-null    object
#  5   place            699 non-null    object
#  6   tweet            699 non-null    object
#  7   language         699 non-null    object
#  8   hashtags         699 non-null    object
#  9   cashtags         699 non-null    object
#  10  user_id          699 non-null    int64
#  11  user_id_str      699 non-null    object
#  12  username         699 non-null    object
#  13  name             699 non-null    object
#  14  day              699 non-null    int64
#  15  hour             699 non-null    object
#  16  link             699 non-null    object
#  17  urls             699 non-null    object
#  18  photos           699 non-null    object
#  19  video            699 non-null    int64
#  20  thumbnail        699 non-null    object
#  21  retweet          699 non-null    bool
#  22  nlikes           699 non-null    int64
#  23  nreplies         699 non-null    int64
#  24  nretweets        699 non-null    int64
#  25  quote_url        699 non-null    object
#  26  search           699 non-null    object
#  27  near             699 non-null    object
#  28  geo              699 non-null    object
#  29  source           699 non-null    object
#  30  user_rt_id       699 non-null    object
#  31  user_rt          699 non-null    object
#  32  retweet_id       699 non-null    object
#  33  reply_to         699 non-null    object
#  34  retweet_date     699 non-null    object
#  35  translate        699 non-null    object
#  36  trans_src        699 non-null    object
#  37  trans_dest       699 non-null    object
#  38  candidates       699 non-null    object
# dtypes: bool(1), float64(1), int64(6), object(31)
# memory usage: 213.7+ KB

# %%
candidates_2023.head(3)
# Out:
#                     id      conversation_id    created_at  \
# 0  1589764392199294977  1589490200282923008  1.667864e+12
# 1  1589762989334618112  1589702301509648384  1.667864e+12
# 2  1589759942428602369  1589759942428602369  1.667863e+12
#
#                   date timezone place  \
# 0  2022-11-08 00:39:02    +0100
# 1  2022-11-08 00:33:27    +0100
# 2  2022-11-08 00:21:21    +0100
#
#                                                tweet language hashtags  \
# 0  @firstladyship Stop worrying yourself over our...       en       []
# 1  @neckobi What's this one tweeting? Deep inside...       en       []
# 2  @officialABAT @ABATMediaCentre @Progressive4BA...       in       []
#
#   cashtags              user_id          user_id_str    username  \
# 0       []            381032519            381032519  ooredolapo
# 1       []            381032519            381032519  ooredolapo
# 2       []  1002899374102413312  1002899374102413312   ABagadozi
#
#                            name  day hour  \
# 0  Asiwaju Jagaban Omo Olodoide    2   00
# 1  Asiwaju Jagaban Omo Olodoide    2   00
# 2       Abubakar Sadiq Bagadozi    2   00
#
#                                                 link urls  \
# 0  https://twitter.com/ooredolapo/status/15897643...   []
# 1  https://twitter.com/ooredolapo/status/15897629...   []
# 2  https://twitter.com/ABagadozi/status/158975994...   []
#
#                                               photos  video  \
# 0                                                 []      0
# 1                                                 []      0
# 2  [https://pbs.twimg.com/media/Fg_2PB3XkAE5nMZ.jpg]      1
#
#                                          thumbnail  retweet  nlikes  nreplies  \
# 0                                                     False       2         0
# 1                                                     False       1         0
# 2  https://pbs.twimg.com/media/Fg_2PB3XkAE5nMZ.jpg    False       0         1
#
#    nretweets quote_url                  search near geo source user_rt_id  \
# 0          0            Asiwaju\Tinubu\Jagaban
# 1          0            Asiwaju\Tinubu\Jagaban
# 2          0            Asiwaju\Tinubu\Jagaban
#
#   user_rt retweet_id                                           reply_to  \
# 0                     [{'screen_name': 'firstladyship', 'name': 'NEF...
# 1                     [{'screen_name': 'neckobi', 'name': 'Nonso Obi...
# 2                                                                    []
#
#   retweet_date translate trans_src trans_dest         candidates
# 0                                              Bola Ahmed Tinubu
# 1                                              Bola Ahmed Tinubu
# 2                                              Bola Ahmed Tinubu

# %%
candidates_2023["language"].unique() # checking if my data has other languages other than English
# Out:
# array(['en', 'in', 'und', 'ht', 'tl', 'ro', 'qam', 'es', 'lv', 'da', 'eu',
#        'fr'], dtype=object)

# %%
# Dropping other languages that are not English
candidates_2023 = candidates_2023[candidates_2023["language"].isin(['en'])]

# %%
candidates_2023["language"].unique() # confirming that other languages are dropped
# Out:
# array(['en'], dtype=object)

# %%
candidates_2023["tweet"][1]
# Out:
# 1    @neckobi What's this one tweeting? Deep inside...
# 1    APC and PDP don’t really see each other as opp...
# 1    @renoomokri Why is ATIKU running away from the...
# Name: tweet, dtype: object

# %%
# checking for dupicate rows
candidates_2023.duplicated(subset = "tweet", keep = 'first').sum() # we had about 139 duplicate rows
# Out:
# 4

# %%
#Dropping the duplicated rows  
candidates_2023 = candidates_2023.drop_duplicates(subset=["tweet"],keep="first")

# %%
candidates_2023.shape # confirming if duplicates are dropped
# Out:
# (634, 39)

# %%
def clean_your_text(text): 
    pat1 = r'@[^ ]+'                   #@signs
    pat2 = r'https?://[A-Za-z0-9./]+'  #links
    pat3 = r'\'s'                      #floating s's
    pat4 = r'\#\w+'                     # hashtags
    pat5 = r'&amp '
    pat6 = r'[^A-Za-z\s]'         #remove non-alphabet
    combined_pat = r'|'.join((pat1, pat2,pat3,pat4,pat5, pat6))
    text = re.sub(combined_pat,"",text).lower()
    return text.strip()

# %%
candidates_2023["tweet"] = candidates_2023["tweet"].apply(clean_your_text)

# %%
candidates_2023.shape
# Out:
# (634, 39)

# %%
candidates_2023["tweet"][1]
# Out:
# 1    what this one tweeting deep inside you you kno...
# 1    apc and pdp dont really see each other as oppo...
# 1     why is atiku running away from the public debate
# Name: tweet, dtype: object

# %%
print("Running sentiment Analysis")

# creating two new columns(polarity and subjectivity)
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

candidates_2023["Subjectivity"] = candidates_2023['tweet'].apply(getSubjectivity)
candidates_2023["Polarity"] = candidates_2023['tweet'].apply(getPolarity)
# Out:
# Running sentiment Analysis
# C:\ProgramData\Anaconda3\lib\collections\__init__.py:414: RuntimeWarning: coroutine 'Twint.main' was never awaited
#   field_names = tuple(map(_sys.intern, field_names))
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
candidates_2023[['Polarity','tweet']]
# Out:
#      Polarity                                              tweet
# 0    0.150000  stop worrying yourself over our next president...
# 1    0.000000  what this one tweeting deep inside you you kno...
# 3    0.700000  this man is too good  tinubushettima is the go...
# 4    0.000000  asiwaju bola ahmed tinubu apc presidential can...
# 5    0.500000  this is where obi can win i will vote for him ...
# ..        ...                                                ...
# 511  0.000000                                   massive disgrace
# 512  0.000000  see your disgraceful self if dem call  now you...
# 513  0.666667  how did know this i know u know hes better tha...
# 514 -0.071429  since  till date una never bring a single evid...
# 515  0.500000  so how does it consign the igbos you ethnic bi...
#
# [634 rows x 2 columns]

# %%
candidates_2023[['Polarity','tweet']]['tweet'].iloc[0]
# Out:
# 'stop worrying yourself over our next president in person of asiwaju bola ahmed tinubu i swear po no fit win even if he the only candidate contesting'

# %%
#creating a column to show if the tweet is positive, negative or neutral
def analysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"

candidates_2023['Analysis'] = candidates_2023['Polarity'].apply(analysis)

# %%
candidates_2023[['Polarity','tweet','Analysis', 'search']]
# Out:
#      Polarity                                              tweet  Analysis  \
# 0    0.150000  stop worrying yourself over our next president...  Positive
# 1    0.000000  what this one tweeting deep inside you you kno...   Neutral
# 3    0.700000  this man is too good  tinubushettima is the go...  Positive
# 4    0.000000  asiwaju bola ahmed tinubu apc presidential can...   Neutral
# 5    0.500000  this is where obi can win i will vote for him ...  Positive
# ..        ...                                                ...       ...
# 511  0.000000                                   massive disgrace   Neutral
# 512  0.000000  see your disgraceful self if dem call  now you...   Neutral
# 513  0.666667  how did know this i know u know hes better tha...  Positive
# 514 -0.071429  since  till date una never bring a single evid...  Negative
# 515  0.500000  so how does it consign the igbos you ethnic bi...  Positive
#
#                      search
# 0    Asiwaju\Tinubu\Jagaban
# 1    Asiwaju\Tinubu\Jagaban
# 3    Asiwaju\Tinubu\Jagaban
# 4    Asiwaju\Tinubu\Jagaban
# 5    Asiwaju\Tinubu\Jagaban
# ..                      ...
# 511                   Atiku
# 512                   Atiku
# 513                   Atiku
# 514                   Atiku
# 515                   Atiku
#
# [634 rows x 4 columns]

# %%
candidates_2023["date"] = pd.to_datetime(candidates_2023["date"])

# %%
candidates_2023.head(3)
# Out:
#                     id      conversation_id    created_at                date  \
# 0  1589764392199294977  1589490200282923008  1.667864e+12 2022-11-08 00:39:02
# 1  1589762989334618112  1589702301509648384  1.667864e+12 2022-11-08 00:33:27
# 3  1589759791446241280  1589699071740383233  1.667863e+12 2022-11-08 00:20:45
#
#   timezone place                                              tweet language  \
# 0    +0100        stop worrying yourself over our next president...       en
# 1    +0100        what this one tweeting deep inside you you kno...       en
# 3    +0100        this man is too good  tinubushettima is the go...       en
#
#   hashtags cashtags              user_id          user_id_str     username  \
# 0       []       []            381032519            381032519   ooredolapo
# 1       []       []            381032519            381032519   ooredolapo
# 3       []       []  1508999743048978437  1508999743048978437  Jagaban_Olu
#
#                            name  day hour  \
# 0  Asiwaju Jagaban Omo Olodoide    2   00
# 1  Asiwaju Jagaban Omo Olodoide    2   00
# 3             Adekunle Olushola    2   00
#
#                                                 link urls photos  video  \
# 0  https://twitter.com/ooredolapo/status/15897643...   []     []      0
# 1  https://twitter.com/ooredolapo/status/15897629...   []     []      0
# 3  https://twitter.com/Jagaban_Olu/status/1589759...   []     []      0
#
#   thumbnail  retweet  nlikes  nreplies  nretweets quote_url  \
# 0              False       2         0          0
# 1              False       1         0          0
# 3              False       0         0          0
#
#                    search near geo source user_rt_id user_rt retweet_id  \
# 0  Asiwaju\Tinubu\Jagaban
# 1  Asiwaju\Tinubu\Jagaban
# 3  Asiwaju\Tinubu\Jagaban
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'firstladyship', 'name': 'NEF...
# 1  [{'screen_name': 'neckobi', 'name': 'Nonso Obi...
# 3  [{'screen_name': 'AjuriNgelale', 'name': 'Ajur...
#
#   trans_src trans_dest         candidates  Subjectivity  Polarity  Analysis
# 0                       Bola Ahmed Tinubu          0.45      0.15  Positive
# 1                       Bola Ahmed Tinubu          0.40      0.00   Neutral
# 3                       Bola Ahmed Tinubu          0.60      0.70  Positive

# %%
# first get the mean of the candidates
candidates_2023.groupby(['search']).mean()
# Out:
#                           created_at       user_id       day     video  \
# search
# Asiwaju\Tinubu\Jagaban  1.667618e+12  8.166559e+17  3.305970  0.328358
# Atiku                   1.667863e+12  8.072054e+17  1.701245  0.070539
# PO\Peter Obi\ObiDatti   1.667539e+12  1.130078e+18  3.888889  0.166667
#
#                         retweet     nlikes  nreplies  nretweets  Subjectivity  \
# search
# Asiwaju\Tinubu\Jagaban      0.0  45.597015  4.820896  14.835821      0.418895
# Atiku                       0.0   6.091286  0.684647   1.419087      0.337410
# PO\Peter Obi\ObiDatti       0.0   5.611111  0.000000   1.277778      0.381506
#
#                         Polarity
# search
# Asiwaju\Tinubu\Jagaban  0.160799
# Atiku                   0.059607
# PO\Peter Obi\ObiDatti   0.267923

# %%
df = candidates_2023[['search','Polarity','Analysis']]
df
# Out:
#                      search  Polarity  Analysis
# 0    Asiwaju\Tinubu\Jagaban  0.150000  Positive
# 1    Asiwaju\Tinubu\Jagaban  0.000000   Neutral
# 3    Asiwaju\Tinubu\Jagaban  0.700000  Positive
# 4    Asiwaju\Tinubu\Jagaban  0.000000   Neutral
# 5    Asiwaju\Tinubu\Jagaban  0.500000  Positive
# ..                      ...       ...       ...
# 511                   Atiku  0.000000   Neutral
# 512                   Atiku  0.000000   Neutral
# 513                   Atiku  0.666667  Positive
# 514                   Atiku -0.071429  Negative
# 515                   Atiku  0.500000  Positive
#
# [634 rows x 3 columns]

# %%
# getting only positive tweets since the question is to get candidate with most positive comment
df1 = df[(df['Analysis']=='Positive')]
df1
# Out:
#                      search  Polarity  Analysis
# 0    Asiwaju\Tinubu\Jagaban  0.150000  Positive
# 3    Asiwaju\Tinubu\Jagaban  0.700000  Positive
# 5    Asiwaju\Tinubu\Jagaban  0.500000  Positive
# 7    Asiwaju\Tinubu\Jagaban  0.500000  Positive
# 10   Asiwaju\Tinubu\Jagaban  0.357143  Positive
# ..                      ...       ...       ...
# 508                   Atiku  0.100000  Positive
# 509                   Atiku  0.100000  Positive
# 510                   Atiku  0.100000  Positive
# 513                   Atiku  0.666667  Positive
# 515                   Atiku  0.500000  Positive
#
# [277 rows x 3 columns]

# %%
# plotting a barplot
fig = plt.figure(figsize =(8, 6))
plt.xticks(rotation=30)
sns.barplot(data=df1, x='search', y='Polarity').set(title='Candidate With Most Positive Tweets', 
                                                    xlabel ='Candidates', ylabel = 'Positive Tweets');

# %% [markdown]
# #### OBSERVATION
# The analysis shows that Peter Obi has the most polarity (positive tweets) among the other political opponent. Followed by Tinubu and then Atiku.

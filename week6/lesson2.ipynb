# %%
import pandas as pd
import numpy as np

# %%
car_prices = pd.read_csv("Nigerian_Car_Prices.csv", index_col=0) # Index-_col=0 is used to remove the column called 'unnamed'
car_prices.head(10)
# Out:
#             Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 0         Toyota               2007.0  Nigerian Used  166418.0       2400.0
# 1          Lexus                  NaN            NaN  138024.0          NaN
# 2  Mercedes-Benz               2008.0  Nigerian Used  376807.0       3000.0
# 3          Lexus                  NaN            NaN  213362.0          NaN
# 4  Mercedes-Benz                  NaN            NaN  106199.0          NaN
# 5  Mercedes-Benz                  NaN            NaN   87660.0          NaN
# 6          Lexus                  NaN            NaN  191411.0          NaN
# 7          Lexus                  NaN            NaN   59092.0          NaN
# 8  Mercedes-Benz                  NaN            NaN   89423.0          NaN
# 9          Lexus                  NaN            NaN  184827.0          NaN
#
#      Fuel Transmission      Price Build
# 0  Petrol    Automatic  3,120,000   NaN
# 1     NaN    Automatic  5,834,000   NaN
# ...

# %%
car_prices.shape
# Out:
# (4095, 10)

# %%
car_prices.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Year of manufacture', 'Condition', 'Mileage',
#        'Engine Size', 'Fuel', 'Transmission', 'Price', 'Build'],
#       dtype='object')

# %%
car_prices.dtypes
# Out:
# Make                    object
# Year of manufacture    float64
# Condition               object
# Mileage                float64
# Engine Size            float64
# Fuel                    object
# Transmission            object
# Price                   string
# Build                   object
# dtype: object

# %%
car_prices.describe()
# Out:
#         Unnamed: 0  Year of manufacture       Mileage    Engine Size
# count  4095.000000          3617.000000  4.024000e+03    3584.000000
# mean   2047.000000          2007.898535  1.825337e+05    3274.976562
# std    1182.269005             4.300126  2.109233e+05    7693.489588
# min       0.000000          1992.000000  1.000000e+00       3.000000
# 25%    1023.500000          2005.000000  1.020640e+05    2000.000000
# 50%    2047.000000          2008.000000  1.613525e+05    2500.000000
# 75%    3070.500000          2011.000000  2.319522e+05    3500.000000
# max    4094.000000          2021.000000  9.976050e+06  371000.000000

# %%
car_prices.isna().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture     478
# Condition               479
# Mileage                  71
# Engine Size             511
# Fuel                    488
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %% [markdown]
# Q1: What is the most expensive Automatic car (show car name and model make) with a mileage of less than 50000

# %% [markdown]
# Q2: Write a function to bring out the average of each car, which car make has the highest average price? Write a code to show this

# %% [markdown]
# Q3: Select the row with a price at the 76th percentile score

# %%
car_prices[(car_prices["Transmission"] =="Automatic") | (car_prices["Price"].max())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\STUTERN\Desktop\Intermediate_project\myenv\lib\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
car_prices.head(10)
# Out:
#    Unnamed: 0           Make  Year of manufacture      Condition   Mileage  \
# 0           0         Toyota               2007.0  Nigerian Used  166418.0
# 1           1          Lexus                  NaN            NaN  138024.0
# 2           2  Mercedes-Benz               2008.0  Nigerian Used  376807.0
# 3           3          Lexus                  NaN            NaN  213362.0
# 4           4  Mercedes-Benz                  NaN            NaN  106199.0
# 5           5  Mercedes-Benz                  NaN            NaN   87660.0
# 6           6          Lexus                  NaN            NaN  191411.0
# 7           7          Lexus                  NaN            NaN   59092.0
# 8           8  Mercedes-Benz                  NaN            NaN   89423.0
# 9           9          Lexus                  NaN            NaN  184827.0
#
#    Engine Size    Fuel Transmission      Price Build
# 0       2400.0  Petrol    Automatic  3,120,000   NaN
# ...

# %%
new_price = car_prices['Price'] == car_prices.groupby(['Price'])['Price'].transform(max)
car_prices.query("Price == @new_price")
# Out:
# Empty DataFrame
# Columns: [Make, Year of manufacture, Condition, Mileage, Engine Size, Fuel, Transmission, Price, Build]
# Index: []

# %%
car_prices['Price'].describe()
# Out:
# count          4095
# unique          579
# top       2,625,000
# freq            113
# Name: Price, dtype: object

# %%
car_prices.Price.describe()
# Out:
# count          4095
# unique          579
# top       2,625,000
# freq            113
# Name: Price, dtype: object

# %%
#car_prices[car_prices['Price'] == car_prices.groupby('Make')['Price'].transform(max)]
#car_prices[car_prices['Price'] == car_prices['Price'].max()] # extract max price
car_prices[car_prices['Price'] == car_prices['Price'].max()]
# Out:
#           Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 3652  Chrysler               1999.0  Nigerian Used  314115.0       3300.0
# 3698       BMW               2002.0  Nigerian Used  335038.0       2500.0
# 3701     Honda               2004.0  Nigerian Used  272575.0       2400.0
# 3734       BMW               2002.0  Nigerian Used  335038.0       2500.0
# 3737     Honda               2004.0  Nigerian Used  272575.0       2400.0
# 3765     Honda               2003.0  Nigerian Used  345282.0       3000.0
# 3787     Honda               2003.0  Nigerian Used  345282.0       3000.0
# 3789     Honda               2005.0  Nigerian Used  579135.0       3000.0
# 3825    Toyota               2001.0  Nigerian Used  244530.0       3000.0
# 3833    Toyota               1999.0  Nigerian Used  198658.0       3000.0
# 3867   Hyundai               2004.0  Nigerian Used   92477.0       2000.0
#
#         Fuel Transmission    Price Build
# ...

# %%
car_prices.head(2)
# Out:
#      Make  Year of manufacture      Condition   Mileage  Engine Size    Fuel  \
# 0  Toyota               2007.0  Nigerian Used  166418.0       2400.0  Petrol
# 1   Lexus                  NaN            NaN  138024.0          NaN     NaN
#
#   Transmission      Price Build
# 0    Automatic  3,120,000   NaN
# 1    Automatic  5,834,000   NaN

# %%
car_prices.quantile([0.75])
# Out:
# C:\Users\STUTERN\AppData\Local\Temp\ipykernel_10280\1385522079.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_prices.quantile([0.75])
#       Year of manufacture    Mileage  Engine Size
# 0.75               2011.0  231952.25       3500.0

# %%
car_prices.query("Mileage =='235569.72'")
# Out:
# Empty DataFrame
# Columns: [Make, Year of manufacture, Condition, Mileage, Engine Size, Fuel, Transmission, Price, Build]
# Index: []

# %%
car_prices.quantile(.76, axis=0, method="table", interpolation='higher')
# Out:
# C:\Users\STUTERN\AppData\Local\Temp\ipykernel_10280\2411529013.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_prices.quantile(.76, axis=0, method="table", interpolation='higher')
# Year of manufacture     2013.0
# Mileage                94561.0
# Engine Size             1800.0
# Name: 0.76, dtype: float64

# %%
car_prices.quantile(.76, axis=0)
# Out:
# C:\Users\STUTERN\AppData\Local\Temp\ipykernel_10280\3603243046.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_prices.quantile(.76, axis=0)
# Year of manufacture      2011.00
# Mileage                235569.72
# Engine Size              3500.00
# Name: 0.76, dtype: float64

# %%
help(car_prices.quantile)
# Out:
# Help on method quantile in module pandas.core.frame:
#
# quantile(q: 'float | AnyArrayLike | Sequence[float]' = 0.5, axis: 'Axis' = 0, numeric_only: 'bool | lib.NoDefault' = <no_default>, interpolation: 'QuantileInterpolation' = 'linear', method: "Literal['single', 'table']" = 'single') -> 'Series | DataFrame' method of pandas.core.frame.DataFrame instance
#     Return values at the given quantile over requested axis.
#
#     Parameters
#     ----------
#     q : float or array-like, default 0.5 (50% quantile)
#         Value between 0 <= q <= 1, the quantile(s) to compute.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Equals 0 or 'index' for row-wise, 1 or 'columns' for column-wise.
#     numeric_only : bool, default True
#         If False, the quantile of datetime and timedelta data will be
#         computed as well.
#
#         .. deprecated:: 1.5.0
#             The default value of ``numeric_only`` will be ``False`` in a future
# ...

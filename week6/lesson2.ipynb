# %% [markdown]
# ### **Nigerian Car Price Dataset**
#
# #### In this Assignment, we're working with the Nigerian Car Price Dataset
# #### -*What is the most expensive Automatic car (show car name and model make) with a mileage of less than 50000*
# #### -*Write a function to bring out the average of each car, which car make has the highest average price? Write a code to show this*
# #### -*Select the row with a price at the 76th percentile score*

# %%
#importing the needed modules
import pandas as pd 
import numpy as np

# %%
# Reading the Nigerian_Car_Prices dataset
car_prices = pd.read_csv("Nigerian_Car_Prices.csv", index_col=0) # Index-_col=0 is used to remove the column called 'unnamed'
car_prices.head()
# Out:
#             Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 0         Toyota               2007.0  Nigerian Used  166418.0       2400.0
# 1          Lexus                  NaN            NaN  138024.0          NaN
# 2  Mercedes-Benz               2008.0  Nigerian Used  376807.0       3000.0
# 3          Lexus                  NaN            NaN  213362.0          NaN
# 4  Mercedes-Benz                  NaN            NaN  106199.0          NaN
#
#      Fuel Transmission      Price Build
# 0  Petrol    Automatic  3,120,000   NaN
# 1     NaN    Automatic  5,834,000   NaN
# 2  Petrol    Automatic  3,640,000   NaN
# 3     NaN    Automatic  3,594,000   NaN
# 4     NaN    Automatic  8,410,000   NaN

# %%
# checking the shape of the dataset
car_prices.shape
# Out:
# (4095, 9)

# %%
# checking the column the label
car_prices.columns
# Out:
# Index(['Make', 'Year of manufacture', 'Condition', 'Mileage', 'Engine Size',
#        'Fuel', 'Transmission', 'Price', 'Build'],
#       dtype='object')

# %%
# checking the coulmns datatypes 
car_prices.dtypes
# Out:
# Make                    object
# Year of manufacture    float64
# Condition               object
# Mileage                float64
# Engine Size            float64
# Fuel                    object
# Transmission            object
# Price                   object
# Build                   object
# dtype: object

# %%
# checking if there are missing values. And there are indeed a lot of missing values, but for the sake of the question,
# we're not going to fill them
car_prices.isna().sum()
# Out:
# Make                      0
# Year of manufacture     478
# Condition               479
# Mileage                  71
# Engine Size             511
# Fuel                    488
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %%
# Removing comma from the values in the Price column
car_prices['Price'] = car_prices['Price'].str.replace(',','')
car_prices['Price'].head()
# Out:
# 0    3120000
# 1    5834000
# 2    3640000
# 3    3594000
# 4    8410000
# Name: Price, dtype: object

# %%
# converting the dtype of Price column from object to float
car_prices["Price"] = car_prices["Price"].astype(float)

# %%
car_prices.dtypes
# Out:
# Make                    object
# Year of manufacture    float64
# Condition               object
# Mileage                float64
# Engine Size            float64
# Fuel                    object
# Transmission            object
# Price                  float64
# Build                   object
# dtype: object

# %%
car_prices.head()
# Out:
#             Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 0         Toyota               2007.0  Nigerian Used  166418.0       2400.0
# 1          Lexus                  NaN            NaN  138024.0          NaN
# 2  Mercedes-Benz               2008.0  Nigerian Used  376807.0       3000.0
# 3          Lexus                  NaN            NaN  213362.0          NaN
# 4  Mercedes-Benz                  NaN            NaN  106199.0          NaN
#
#      Fuel Transmission    Price Build
# 0  Petrol    Automatic  3120000   NaN
# 1     NaN    Automatic  5834000   NaN
# 2  Petrol    Automatic  3640000   NaN
# 3     NaN    Automatic  3594000   NaN
# 4     NaN    Automatic  8410000   NaN

# %%
# Describing the dataset to have more insight
car_prices.describe()
# Out:
#        Year of manufacture       Mileage    Engine Size         Price
# count          3617.000000  4.024000e+03    3584.000000  4.095000e+03
# mean           2007.898535  1.825337e+05    3274.976562  4.271288e+06
# std               4.300126  2.109233e+05    7693.489588  4.900064e+06
# min            1992.000000  1.000000e+00       3.000000  4.580000e+05
# 25%            2005.000000  1.020640e+05    2000.000000  1.872000e+06
# 50%            2008.000000  1.613525e+05    2500.000000  2.940000e+06
# 75%            2011.000000  2.319522e+05    3500.000000  4.725000e+06
# max            2021.000000  9.976050e+06  371000.000000  5.880000e+07

# %% [markdown]
# Q1: What is the most expensive Automatic car (show car name and model make) with a mileage of less than 50000

# %%
car_prices["Price"].max()
# Out:
# 58800000.0

# %%
car_prices.head()
# Out:
#             Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 0         Toyota               2007.0  Nigerian Used  166418.0       2400.0
# 1          Lexus                  NaN            NaN  138024.0          NaN
# 2  Mercedes-Benz               2008.0  Nigerian Used  376807.0       3000.0
# 3          Lexus                  NaN            NaN  213362.0          NaN
# 4  Mercedes-Benz                  NaN            NaN  106199.0          NaN
#
#      Fuel Transmission      Price Build
# 0  Petrol    Automatic  3120000.0   NaN
# 1     NaN    Automatic  5834000.0   NaN
# 2  Petrol    Automatic  3640000.0   NaN
# 3     NaN    Automatic  3594000.0   NaN
# 4     NaN    Automatic  8410000.0   NaN

# %%
x = car_prices['Price'].max()
x
# Out:
# 58800000.0

# %%
Most_Expensive_Automatic_Car = car_prices[(car_prices["Transmission"]=="Automatic") & (car_prices["Mileage"] < 50000) & (car_prices['Price'].max())]
Most_Expensive_Automatic_Car
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:315, in na_logical_op(x, y, op)
#     314 try:
# --> 315     result = libops.scalar_binop(x, y, op)
#     316 except (
#     317     TypeError,
#     318     ValueError,
#    (...)
#     321     NotImplementedError,
#     322 ) as err:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\ops.pyx:180, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'bool'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\STUTERN\Desktop\Intermediate_project\week6\lesson2.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/STUTERN/Desktop/Intermediate_project/week6/lesson2.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> Most_Expensive_Automatic_Car = car_prices[(car_prices["Transmission"]=="Automatic") & (car_prices["Mileage"] < 50000) & (car_prices['Price'].max())]
#       <a href='vscode-notebook-cell:/c%3A/Users/STUTERN/Desktop/Intermediate_project/week6/lesson2.ipynb#X65sZmlsZQ%3D%3D?line=1'>2</a> Most_Expensive_Automatic_Car
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:5634, in Series._logical_method(self, other, op)
#    5631 lvalues = self._values
#    5632 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5634 res_values = ops.logical_op(lvalues, rvalues, op)
#    5635 return self._construct_result(res_values, name=res_name)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:391, in logical_op(left, right, op)
#     387 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     388 #   integer dtypes.  Otherwise these are boolean ops
#     389 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 391 res_values = na_logical_op(lvalues, rvalues, op)
#     392 # error: Cannot call function of unknown type
#     393 res_values = filler(res_values)  # type: ignore[operator]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:324, in na_logical_op(x, y, op)
#     316         except (
#     317             TypeError,
#     318             ValueError,
#    (...)
#     321             NotImplementedError,
#     322         ) as err:
#     323             typ = type(y).__name__
# --> 324             raise TypeError(
#     325                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     326                 f"and scalar of type [{typ}]"
#     327             ) from err
#     329 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'and_' with a dtyped [bool] array and scalar of type [bool]

# %%
car_prices[car_prices['Price'] == car_prices.groupby('Make')['Price'].transform(max)]
# Out:
#             Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 15          Fiat                  NaN            NaN      54.0          NaN
# 27         Foton                  NaN            NaN   54470.0          NaN
# 40           JAC                  NaN            NaN   35403.0          NaN
# 54         Lexus               2016.0  Nigerian Used  107355.0       5700.0
# 122         Tata               2008.0   Foreign Used       NaN     371000.0
# ...          ...                  ...            ...       ...          ...
# 3662    Daihatsu               1997.0  Nigerian Used  305854.0       1800.0
# 3897  Volkswagen               2018.0   Foreign Used   72831.0       2000.0
# 3930  Volkswagen               2018.0   Foreign Used   72831.0       2000.0
# 4008       Mazda               2014.0   Foreign Used   94365.0       3500.0
# 4027     Changan               2020.0  Nigerian Used   24019.0        200.0
#
#         Fuel Transmission       Price Build
# 15       NaN       Manual  12500000.0   NaN
# 27       NaN       Manual   4938000.0   NaN
# 40       NaN    Automatic   7850000.0   NaN
# 54    Petrol    Automatic  42000000.0   SUV
# 122   Diesel       Manual  17850000.0   NaN
# ...      ...          ...         ...   ...
# 3662  Petrol       Manual    945000.0   NaN
# 3897  Petrol    Automatic  27300000.0   NaN
# 3930  Petrol    Automatic  27300000.0   NaN
# 4008  Petrol    Automatic   8437500.0   SUV
# 4027  Petrol    Automatic  20250000.0   SUV
#
# [72 rows x 9 columns]

# %%
car_prices[car_prices['Price'] == car_prices['Price'].max()]
# Out:
#           Make  Year of manufacture      Condition   Mileage  Engine Size  \
# 3652  Chrysler               1999.0  Nigerian Used  314115.0       3300.0
# 3698       BMW               2002.0  Nigerian Used  335038.0       2500.0
# 3701     Honda               2004.0  Nigerian Used  272575.0       2400.0
# 3734       BMW               2002.0  Nigerian Used  335038.0       2500.0
# 3737     Honda               2004.0  Nigerian Used  272575.0       2400.0
# 3765     Honda               2003.0  Nigerian Used  345282.0       3000.0
# 3787     Honda               2003.0  Nigerian Used  345282.0       3000.0
# 3789     Honda               2005.0  Nigerian Used  579135.0       3000.0
# 3825    Toyota               2001.0  Nigerian Used  244530.0       3000.0
# 3833    Toyota               1999.0  Nigerian Used  198658.0       3000.0
# 3867   Hyundai               2004.0  Nigerian Used   92477.0       2000.0
#
#         Fuel Transmission    Price Build
# 3652  Petrol    Automatic  997,500   NaN
# 3698  Petrol    Automatic  997,500   NaN
# 3701  Petrol    Automatic  997,500   NaN
# 3734  Petrol    Automatic  997,500   NaN
# 3737  Petrol    Automatic  997,500   NaN
# 3765  Petrol    Automatic  997,500   NaN
# 3787  Petrol    Automatic  997,500   NaN
# 3789  Petrol    Automatic  997,500   NaN
# 3825  Petrol    Automatic  997,500   NaN
# 3833  Petrol    Automatic  997,500   NaN
# 3867  Petrol    Automatic  997,500   NaN

# %% [markdown]
# **Q2: Write a function to bring out the average of each car, which car make has the highest average price? Write a code to show this**

# %%
# Average price of each car

def average_price(average):
    average['Make'] = average[['Price'].mean()]
    return average['Make']

# %% [markdown]
# **Q3: Select the row with a price at the 76th percentile score**

# %%
car_prices.quantile([0.76], axis=0)
# Out:
#       Year of manufacture    Mileage  Engine Size      Price
# 0.76               2011.0  235569.72       3500.0  4770000.0

# %% [markdown]
# The 76th percentile falls at **Price of 4770,000.0**

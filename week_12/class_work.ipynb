# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('C:/Users/STUTERN/Downloads/ds-application-exercise-final.xlsx', index_col=0)

# %%
df.head()
# Out:
#    ID_ORIGINAL  Gender Foreign_Citizenship  Age Frequent_Traveler  \
# 0       467329  Female                  No   40               Yes
# 1       461212  Female                  No   30                No
# 2       466216    Male                  No   29                No
# 3       462613  Female                 Yes   35                No
# 4       465709    Male                 Yes   68               Yes
#
#   Cellphone_Usage  Household_Size  Spy  Satisfaction_Level       Occupation  \
# 0             Low               1    1                   4       Government
# 1             Low               6    0                   1          Nothing
# 2             Low               4    0                   1  Private company
# 3         Average               5    0                   1  Private company
# 4         Average               2    1                   4  Private company
#
#   Political_Participation Social_Person Area_Residence Military_Service  \
# ...

# %%
df.shape
# Out:
# (7823, 20)

# %% [markdown]
# missing values
# EDA
# Clone your dataset
# Preprocessing; treat your categorical columns, treat outliers, skewed columns etc
# fitting the model
# Evaluating the model
# Fine tune

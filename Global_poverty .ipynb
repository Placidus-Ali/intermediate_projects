# %% [markdown]
# The dataset you provided contains various socio-economic indicators for different countries and years. Here are some insights you can draw from this dataset:
#
# Poverty Rates: You can analyze the headcount ratios to understand the percentage of people living below different poverty lines (e.g., international poverty line, lower mid-income poverty line, upper mid-income poverty line). This can give you insights into the poverty levels and how they vary across countries and years.
#
# Income Distribution: The dataset provides information about the income distribution, such as the Gini coefficient, decile shares, and income gap ratios. You can analyze these measures to understand the level of income inequality within countries and how it changes over time.
#
# Welfare Programs: By examining the welfare types and their coverage, you can gain insights into the effectiveness of welfare programs in addressing poverty and inequality. You can compare different countries and years to identify patterns and trends.
#
# International Comparisons: The dataset includes international poverty lines and indicators, allowing you to compare poverty rates and income disparities across countries. This can help you understand the relative performance of different nations in terms of poverty reduction and income equality.
#
# Time Trends: By analyzing the data over different years, you can identify trends and patterns in poverty rates, income distribution, and welfare indicators. This can provide insights into the impact of social and economic changes on poverty and inequality.
#
# Correlations: You can explore correlations between different variables to uncover relationships. For example, you could examine the relationship between income inequality (measured by the Gini coefficient) and poverty rates to see if there is a connection between these two factors.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/STUTERN/Downloads/Global_poverty_and_inequality_dataset/pip_dataset.csv")
df.head()
# Out:
#    country  year reporting_level welfare_type  ppp_version  survey_year  \
# 0  Albania  1996        national  consumption         2011       1996.0
# 1  Albania  2002        national  consumption         2011       2002.0
# 2  Albania  2005        national  consumption         2011       2005.0
# 3  Albania  2008        national  consumption         2011       2008.0
# 4  Albania  2012        national  consumption         2011       2012.0
#
#    survey_comparability  headcount_ratio_international_povline  \
# 0                   0.0                               0.920669
# 1                   1.0                               1.570843
# 2                   1.0                               0.860527
# 3                   1.0                               0.313650
# 4                   1.0                               0.849754
#
#    headcount_ratio_lower_mid_income_povline  \
# 0                                 11.174149
# 1                                 14.132118
# ...

# %% [markdown]
# In this assigment, we going to scrap a site and draw insights from it
#
# * using the url above webscrap the financial website and load it in a pandas Dataframe
# * load it in df and draw out 3  insights from the data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.cbn.gov.ng/rates/ExchRateByCurrency.asp"
r = requests.get(url)
content = BeautifulSoup(r.content, 'html.parser')
content
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="Exchange Rate Ordered By Currency " name="Description"/>
# <meta content="OMO, Bid, Tenure, rates, CBN, Central Bank of Nigeria, Financial Data, Forex, auction" name="keywords"/>
# <title>Central Bank of Nigeria | Exchange Rate </title>
# <link href="/stylesheets/newstyle.css" rel="stylesheet" type="text/css"/>
# <link href="images/icons/favicon.ico" rel="shortcut icon"/>
# <link href="/stylesheets/core.css" rel="stylesheet" type="text/css"/>
# <script src="https://ajax.aspnetcdn.com/ajax/jQuery/jquery-3.4.1.js" type="text/javascript"></script>
# <!--[if lt IE 9]>
#   <script src="/scripts/html5shiv.js"></script>
# <![endif]-->
# <style>
# #chartdiv {
#   width: 100%;
#   height: 850px;
# }
# </style>
# <script src="/amcharts_4.0.8/amcharts4/core.js"></script>
# <script src="/amcharts_4.0.8/amcharts4/charts.js"></script>
# <script src="/amcharts_4.0.8/amcharts4/themes/animated.js"></script>
# <link href="//cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css" rel="stylesheet" type="text/css">
# <script src="//cdn.datatables.net/plug-ins/1.10.20/sorting/datetime-moment.js" type="text/javascript"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/moment.js/2.8.4/moment.min.js" type="text/javascript"></script>
# <script src="//cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# $(document).ready(function() {
#     $('#exTable').DataTable( {
#         "ajax": "outputExchangeRateJSN.asp",
#         columnDefs: [ { type: 'date', 'targets': [0] } ], //This is to enable display sorted by date by default, 0 is the index of the column that has the date with which you want to sort.
#         order: [[ 0, 'desc' ]],   //0 is the index of the column that has the date with which you want to sort.
#        "dataSrc":"data",
#         "columns": [
#             { "data": "ratedate" },
#             { "data": "currency" },
#             { "data": "buyingrate" },
#             { "data": "centralrate" },
#             { "data": "sellingrate" }
#         ]
#     } );
# } );
#
# </script>
# </link></meta></head>
# <body>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KL2TZNN" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="topmenu">
# <div align="right">
# <table>
# <tr>
# <td><a href="/">Home</a> | <a href="/AboutCBN">About Us</a> | <a href="/FAQS/FAQ.asp">FAQs</a> | <a href="/RSS/createrssfromdb.asp">RSS</a> | <a href="/Contacts">Contact Us</a> | <a href="/sitemap.asp">Sitemap</a> | <a href="#">Careers</a> | <a href="/Educational.asp">Educational</a> | <a href="/FOI">Freedom of Information</a></td>
# <td> </td>
# <td> </td>
# <td>
# <div class="lighter">
# <div style="width: 280px;">
# <script>
#   (function() {
#     var cx = '002460506235170613914:dtusfyay-qa';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#                             </script>
# <gcse:searchbox-only queryparametername="q" resultsurl="/search/runsearch.asp"></gcse:searchbox-only>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div id="container">
# <div id="header">
# <div id="mastbanner">
# <link href="/stylesheets/newbanner.css" rel="stylesheet" type="text/css"/>
# <div class="newbanner">
# <a class="hoverNoBorder" href="/"><img class="newlogo" longdesc="http://www.cbn.gov.ng" src="/images/HighResoultion/cbnlogotrans.gif"/></a>
# <div class="menu">
# </div>
# <p class="masttext">Central Bank of Nigeria</p>
# </div>
# </div>
# <link href="/stylesheets/menu5.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="/scripts/largemenuscripts.js" type="text/javascript"></script>
# <link href="/stylesheets/pure-min.css" rel="stylesheet" type="text/css">
# <div class="megamenu_wrapper megamenu_light_theme">
# <div class="megamenu_container megamenu_lightblue">
# <ul class="megamenu">
# <li class="megamenu_button"></li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">MONETARY POLICY</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/MonetaryPolicy/calendar.asp" target="_self">Calendar of Meetings</a></li>
# <li><a href="/MonetaryPolicy/Fiscal.asp" target="_top">Fiscal Policy</a></li>
# <li><a href="/documents/Monetarycreditguide.asp" target="_top">Monetary, Credit, Foreign Trade and Exchange policy Guidelines</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/MonetaryPolicy/Conduct.asp" target="_self">Conduct of MPC</a></li>
# <li><a href="/MonetaryPolicy/Committees.asp" target="_top">Committees</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/documents/mpc.asp" target="_top">Policy Communiques</a></li>
# <li><a href="/MonetaryPolicy/decisions.asp" target="_top">Policy Decisions</a></li>
# <li><a href="/documents/ataglanceseries.asp" target="_top">At A Glance Series</a></li>
# <li><a href="/documents/policyreview.asp" target="_top">Monetary Policy Review</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/documents/UMPseries.asp" target="_top">Understanding Monetary Policy Series</a></li>
# <li><a href="/MonetaryPolicy/afcfta.asp" target="_top">AfCFTA</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# <div class="col_half firstcolumn">
# </div>
# <div class="col_half">
# </div>
# </div>
# </div>
# </li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">CURRENCY</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/Currency/" target="_self">Currency</a></li>
# <li><a href="/Currency/gallery.asp" target="_top">Currency Gallery</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Currency/legaltender.asp" target="_self">Legal Tender</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Currency/securityfeatures/SecurityFeatures.asp" target="_top">Security Features</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Currency/historycur.asp" target="_self">History of Nigerian Currency</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# <div class="col_half">
# </div>
# </div>
# </div>
# </li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">DEVELOPMENT FINANCE</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_half firstcolumn">
# </div>
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/devfin/default.asp" target="_self">Development Financing</a></li>
# <li><a href="/devfin/Activities.asp" target="_top">Activities</a></li>
# <li><a href="/documents/microfinewsletter.asp" target="_top">Newsletter</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/devfin/acgsf.asp" target="_top">Agric Credit</a></li>
# <li><a href="/devfin/commoditysurv.asp" target="_top">Commodity Surveillance</a></li>
# <li><a href="/devfin/MAB.asp" target="_self">Microfinance Advisory Board</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/devfin/Microfinance.asp" target="_self">Microfinance</a></li>
# <li><a href="/Devfin/smeeispage.asp" target="_top">SMEEIS</a></li>
# <li><a href="/Devfin/yedp.asp" target="_top">YEDP</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/devfin/refinancing.asp" target="_self">Refinancing &amp; Rediscounting Scheme</a></li>
# <li><a href="/devfin/infrastructurefinance.asp" target="_self">Infrastructure Finance</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# <div class="col_half firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/fininc/" target="_self">Financial Inclusion</a>
# </li>
# </ol>
# </div>
# </div>
# </div>
# </li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">PAYMENTS SYSTEM</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/Paymentsystem/" target="_self">Introduction</a>
# </li>
# <li><a href="/Paymentsystem/RetailPayments.asp" target="_self">Retails Payments</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Paymentsystem/Modes.asp" target="_top">Modes</a></li>
# <li><a href="/Paymentsystem/LargeValuePayments.asp" target="_self">Large Value Payments</a></li>
# <li><a href="/Paymentsystem/ePaymentStatistics.asp">e-Payment Statistics</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Paymentsystem/PSV2020.asp" target="_top">PSV2020</a></li>
# <li><a href="/Paymentsystem/oversight.asp" target="_self">Oversight</a></li>
# <li><a href="/Paymentsystem/PSPs.asp" target="_self">Payments Service Providers</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Documents/BODcirculars.asp" target="_self">Circulars</a></li>
# <li><a href="/Documents/PaymentsSystemGuidelines.asp" target="_self">Guidelines</a></li>
# <li><a href="/Paymentsystem/BVN.asp" target="_self">BVN</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# <div class="col_half">
# </div>
# </div>
# </div></li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">RESERVE MANAGEMENT</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_half firstcolumn">
# </div>
# <div class="col_half">
# <p class="mail"></p>
# <p class="print"></p>
# </div>
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/IntOps/" target="_self">FX Structure</a></li>
# <li><a href="/IntOps/FXManagement.asp" target="_self">FX Mgt Before Now.</a> </li>
# <li><a href="/documents/fxu.asp" target="_self">FX Utilization</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/IntOps/FXMarket.asp" target="_self">FX Mkt</a></li>
# <li><a href="/IntOps/Debt%20Conversion.asp" target="_self">Debt Conversion</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/IntOps/ExchRatePolicy.asp" target="_self">Exch. Rate Policy</a></li>
# <li><a href="/IntOps/Reserve.asp?MoveDate=11/11/2022 12:03:37 PM" target="_top">Movement in Reserves</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/IntOps/Payments.asp?PayDate=11/11/2022 12:03:37 PM">International Payments</a></li>
# <li><a href="/IntOps/ReserveMgmt.asp" target="_self">Reserve Management</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# </div>
# </div>
# </li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">FINANCIAL STABILITY</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_half firstcolumn">
# <p class="help"></p>
# </div>
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/Supervision/" target="_top">Supervision</a></li>
# <li><a href="/Supervision/crms.asp" target="_top">Credit Risk Management</a></li>
# <li><a href="/Supervision/mfbreturns.asp" target="_top">Microfinance Monthly Returns Guide</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/Supervision/finstitutions.asp" target="_top">Financial Institutions</a></li>
# <li><a href="/Supervision/cpd.asp" target="_top">Consumer Protection</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/documents/bsdpublications.asp" target="_top">Supervision Publications</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/documents/bsdcirculars.asp" target="_top">Supervision Circulars &amp; Guidelines</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# </div>
# </div>
# </li>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">STATISTICS</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_half firstcolumn">
# <p class="favorite"></p>
# <p class="help"></p>
# </div>
# <div class="col_half">
# <p class="mail"></p>
# <p class="print"></p>
# </div>
# <div class="col_one_quarter firstcolumn">
# <ol style="list-style-type:square">
# <li><a href="/rates/crudeoil.asp">Crude Oil Price</a></li>
# <li><a href="/rates/DiscWindow.asp" target="_self">Discount Windows</a></li>
# <li><a href="/rates/MacroIndicators.asp">Economic/Macro Indicators</a></li>
# <li><a href="/rates/ExchRateByCurrency.asp">Exchange Rates</a></li>
# <li><a href="/rates/FinancialData.asp" target="_self">Financial Data</a></li>
# <li><a href="/rates/DailyCrude.asp" target="_self">Daily Crude Oil Price</a></li>
# <li><a href="/rates/dutch.asp" target="_self">Foreign Exchange WDAS  Spot</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/rates/GovtSecuritiesDrillDown.asp">Government Securities  Details</a></li>
# <li><a href="/rates/GovtSecurities.asp" target="_self">Government Securities  Summary</a></li>
# <li><a href="/rates/NominalGDP.asp">Gross Domestic Product  - Nominal</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/rates/RealGDP.asp">Gross Domestic Product  - Real</a></li>
# <li><a href="/rates/inflrates.asp">Inflation</a></li>
# <li><a href="/rates/interbankrates.asp" target="_self">Inter-bank Rates</a></li>
# <li><a href="/IntOps/Payments.asp?PayDate=11/11/2022 12:03:37 PM">International Payments</a></li>
# <li><a href="/documents/BuyersGuide.asp" target="_top">Items &amp; Publications for  Sale</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <ol style="list-style-type:square">
# <li><a href="/rates/mnycredit.asp">Money and Credit  Statistics</a></li>
# <li><a href="/rates/mnymktind.asp">Money Market Indicators</a></li>
# <li><a href="/rates/exrate.asp">Monthly Average  Exchange Rates of the  Naira</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_third">
# <br/>
# <ol style="list-style-type:square">
# <li><a href="/IntOps/Reserve.asp?MoveDate=11/11/2022 12:03:37 PM">Movement in Foreign Reserve </a></li>
# <li><a href="/rates/Assets.asp">Statement of Assets &amp; Liabilities</a></li>
# <li><a href="/documents/Statbulletin.asp" target="_top">Statistical Bulletins</a></li>
# <li><a href="http://statistics.cbn.gov.ng/cbn-onlinestats/">Statistics Database</a></li>
# <li><a href="/rates/5YearBalanceSheet.asp" target="_top">Summary of 5 - Year Financial Summary</a></li>
# <li><a href="/rates/5YearBalanceSheet71e.asp">Summary of 5 - Year Financial Summary - Pre 1972</a></li>
# </ol>
# </div>
# <div class="col_half">
# </div>
# <li class="menuitem_fullwidth"><a class="menuitem_drop" href="#_">PUBLICATIONS</a>
# <div class="dropdown_fullwidth">
# <div class="col_two_thirds firstcolumn">
# <div class="col_half firstcolumn">
# <p class="favorite"></p>
# <p class="help"></p>
# </div>
# <div class="col_half">
# <p class="mail"></p>
# <p class="print"></p>
# </div>
# <div class="col_one_quarter firstcolumn">
# <h3>Annual Reports</h3>
# <ol style="list-style-type:square">
# <li><a href="/Documents/cbnannualreports.asp">CBN Annual Reports</a></li>
# <li><a href="/Documents/bsdreports.asp">Banking Supervision</a></li>
# <li><a href="/documents/NeFFar.asp">NeFF</a></li>
# <li><a href="/documents/ffsr.asp">Flow of Funds Statistics Report</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <h3>Other Publications</h3>
# <ol style="list-style-type:square">
# <li><a href="/Documents/efr.asp">Economic and Financial Review</a></li>
# <li><a href="/FinInc/FinIncNewsletter.asp">Financial Inclusion Newsletter</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <h3>Other Publications</h3>
# <ol style="list-style-type:square">
# <li><a href="/documents/PurchManIndex.asp">Purchasing Managers Index</a></li>
# <li><a href="/Documents/acgsf.asp">Agric Credit Guarantee Scheme</a></li>
# <li><a href="/Documents/fmdactivityreports.asp">Financial Markets Activity Reports</a></li>
# </ol>
# </div>
# <div class="col_one_quarter">
# <h3>Statistical Reports</h3>
# <ol style="list-style-type:square">
# <li><a href="/documents/Statbulletin.asp" target="_top">Statistical Bulletins</a></li>
# <li><a href="http://statistics.cbn.gov.ng/cbn-onlinestats/">Statistics Database</a></li>
# <li><a href="/Documents/finstmt.asp">Financial Statements</a></li>
# <li><a href="/Documents/cbnjas.asp">CBN Journal of Applied Statistics</a></li>
# </ol>
# </div>
# </div>
# <div class="col_one_quarter">
# <br/>
# <h3>CBN Economic Reports</h3>
# <ol style="list-style-type:square">
# <li><a href="/Documents/monthlyecoreports.asp">CBN Monthly Economic Reports</a></li>
# <li><a href="/Documents/quarterlyecoreports.asp">CBN Quarterly Economic Reports</a></li>
# <li><a href="/Documents/halfyearreports.asp">CBN Half Year Economic Reports</a></li>
# </ol>
# </div>
# <div class="col_half">
# </div>
# </div>
# </li>
# </div></li></ul>
# </div>
# </div>
# <div class="pagecontentclear"></div>
# </link></div>
# <div id="Breadcrumb"><a href="/">Home</a> &gt; <a href="/rates/default.asp">Data &amp; Statistics</a> &gt; <a href="/rates/ExchRateByCurrency.asp">Exchange Rate By Currency</a></div>
# <div id="content">
# <div id="ContentTextinner">
# <h1>Exchange Rates</h1>
# <h2>Monthly Moving Average</h2>
# <div id="chartdiv"></div><br/>
# <br/>
# <table class="display" id="exTable" style="width:100%"><thead><tr><th>Date</th><th>Currency</th><th>Buying(NGN)</th><th>Central(NGN)</th><th>Selling(NGN)</th></tr></thead><tfoot><tbody></tbody><tr><th>Date</th><th>Currency</th><th>Buying(NGN)</th><th>Central(NGN)</th><th>Selling(NGN)</th></tr></tfoot></table>
# <p>
# <a href="/Functions/export.asp?tablename=exchange" target="_self"><img alt="Export to Excel" border="0" height="15" src="../images/icons/EExcel.gif" width="14"/></a><a href="/Functions/export.asp?tablename=exchange" target="_self"> Export Exchange Rate Results to Excel / CSV </a></p><br/>
# <script>
# //Themes begin
# am4core.useTheme(am4themes_animated);
#
#
# // Create chart instance
# var chart = am4core.create("chartdiv", am4charts.XYChart);
#
#
# // Create axes
# var dateAxis = chart.xAxes.push(new am4charts.DateAxis());
# dateAxis.renderer.minGridDistance = 50;
# dateAxis.renderer.grid.template.location = 0.5;
# dateAxis.startLocation = 0.0;
# dateAxis.endLocation = 0.0;
# dateAxis.title.text = "Date";
#
# var valueAxis = chart.yAxes.push(new am4charts.ValueAxis());
# valueAxis.title.text = "Naira (=N=) - Selling Rate";
#
# chart.dateFormatter.dateFormat = "d MMM, yyyy";
# //dateAxis.dateFormatter = new am4core.DateFormatter();
# //dateAxis.dateFormatter.dateFormat = "MMM, yyyy";
#
#
# // Create series
# var series1 = chart.series.push(new am4charts.LineSeries());
# series1.dataFields.valueY = "Naira";
# series1.dataFields.dateX = "date";
# series1.strokeWidth = 3;
# series1.name = "US DOLLAR";
# series1.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series1.tensionX = 0.8;
# series1.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 428.51
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 428.81
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 429.11
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 429.38
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 429.68
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 430.01
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 430.37
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 430.71
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 431.09
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 431.49
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 431.83
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 432.19
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 432.54
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 432.87
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 433.54
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 433.9
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 434.22
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 434.78
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 435.27
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 435.7
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 436.06
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 436.85
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 436.98
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 437.11
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 437.28
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 437.5
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 437.68
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 437.68
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 438.16
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 438.5
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 438.85
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 439.02
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 439.37
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 439.67
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 439.88
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 440.26
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 440.53
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 440.79
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 441.13
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 441.46
# }, ];
#
#
# var series2 = chart.series.push(new am4charts.LineSeries());
# series2.dataFields.valueY = "Naira";
# series2.dataFields.dateX = "date";
# series2.strokeWidth = 3;
# series2.name = "POUNDS STERLING";
# series2.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series2.tensionX = 0.8;
# series2.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 501.3567
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 502.9512
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 496.137
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 493.4006
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 489.6633
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 489.3084
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 491.4395
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 488.5974
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 487.9939
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 477.6163
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 463.9582
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 466.5491
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 458.5357
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 469.8804
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 491.6777
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 491.5219
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 488.9751
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 487.3449
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 482.4533
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 481.7535
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 491.3524
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 493.3784
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 494.3118
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 491.5739
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 492.2461
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 486.325
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 494.8848
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 495.1474
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 506.6444
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 507.5638
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 507.1789
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 506.6291
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 507.8678
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 506.1921
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 494.2932
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 493.2673
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 504.4509
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 504.6164
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 505.7114
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 502.7346
# }, ];
#
#
# var series3 = chart.series.push(new am4charts.LineSeries());
# series3.dataFields.valueY = "Naira";
# series3.dataFields.dateX = "date";
# series3.strokeWidth = 3;
# series3.name = "EURO";
# series3.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series3.tensionX = 0.8;
# series3.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 435.1091
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 436.4857
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 429.2816
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 428.8218
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 428.348
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 429.58
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 429.3801
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 426.7475
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 425.6583
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 421.0048
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 416.1546
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 416.7176
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 413.984
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 420.7496
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 429.0745
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 429.9081
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 428.0975
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 425.867
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 423.3001
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 423.0211
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 424.8969
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 425.4919
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 429.3765
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 427.6247
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 429.1466
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 426.475
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 430.4583
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 431.6838
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 439.0801
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 439.6401
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 437.0463
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 436.2103
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 436.9974
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 435.4492
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 429.3229
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 431.2787
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 439.737
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 440.5255
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 443.6444
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 439.2968
# }, ];
#
#
# var series4 = chart.series.push(new am4charts.LineSeries());
# series4.dataFields.valueY = "Naira";
# series4.dataFields.dateX = "date";
# series4.strokeWidth = 3;
# series4.name = "SWISS FRANC";
# series4.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series4.tensionX = 0.8;
# series4.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 450.1155
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 451.1415
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 446.2458
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 447.9241
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 446.4672
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 444.5007
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 445.3793
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 446.9801
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 439.2602
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 440.1612
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 435.6638
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 437.9268
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 438.5036
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 440.8943
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 438.8501
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 440.3288
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 440.6983
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 438.8614
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 437.062
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 437.6695
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 436.9777
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 435.8041
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 438.4708
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 435.8895
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 436.146
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 432.1841
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 436.6756
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 436.545
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 442.6753
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 442.0363
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 440.3914
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 439.1078
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 442.6456
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 441.5244
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 434.4065
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 437.1996
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 445.1597
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 444.524
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 448.9873
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 446.2798
# }, ];
#
# var series5 = chart.series.push(new am4charts.LineSeries());
# series5.dataFields.valueY = "Naira";
# series5.dataFields.dateX = "date";
# series5.strokeWidth = 3;
# series5.name = "YEN";
# series5.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series5.tensionX = 0.8;
# series5.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 3.01
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 3.0177
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 2.9962
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 2.9907
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 3.0018
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 2.9945
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 2.9955
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 2.989
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 3.0507
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 3.0223
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 2.994
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 2.9913
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 2.9894
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 2.9911
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 2.9926
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 3.0028
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 3.0004
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 3.0008
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 2.9897
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 2.9712
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 2.9717
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 2.934
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 2.9298
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 2.9207
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 2.9191
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 2.8874
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 2.9365
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 2.9384
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 2.9778
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 2.9864
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 2.9744
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 2.9522
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 2.9861
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 2.9891
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 2.9682
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 2.9788
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 3.0031
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 3.0072
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 3.0275
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 3.0146
# }, ];
#
# var series6 = chart.series.push(new am4charts.LineSeries());
# series6.dataFields.valueY = "Naira";
# series6.dataFields.dateX = "date";
# series6.strokeWidth = 3;
# series6.name = "CFA";
# series6.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series6.tensionX = 0.8;
# series6.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 0.6551
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 0.6626
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 0.6644
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 0.6523
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 0.6533
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 0.6508
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 0.6541
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 0.6544
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 0.6497
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 0.6488
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 0.6403
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 0.6343
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 0.6341
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 0.63
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 0.6436
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 0.652
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 0.6551
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 0.6519
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 0.6486
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 0.6437
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 0.6433
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 0.6452
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 0.6467
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 0.6544
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 0.6506
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 0.653
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 0.6479
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 0.6479
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 0.6479
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 0.6479
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 0.6697
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 0.6645
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 0.6645
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 0.6645
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 0.6633
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 0.6633
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 0.6618
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 0.6703
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 0.6706
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 0.6706
# }, ];
#
# var series7 = chart.series.push(new am4charts.LineSeries());
# series7.dataFields.valueY = "Naira";
# series7.dataFields.dateX = "date";
# series7.strokeWidth = 3;
# series7.name = "WAUA";
# series7.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series7.tensionX = 0.8;
# series7.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 556.8892
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 558.4546
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 559.707
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 555.6937
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 555.361
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 555.0436
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 555.8375
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 556.6945
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 554.9967
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 554.6516
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 551.1337
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 548.6475
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 548.6
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 547.3342
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 553.7276
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 556.9315
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 559.0903
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 558.3061
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 556.9728
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 554.3584
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 554.723
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 555.9923
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 556.0272
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 558.1531
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 557.0358
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 557.4986
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 555.903
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 555.903
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 555.903
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 555.903
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 564.7521
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 563.014
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 563.014
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 563.014
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 563.6088
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 563.6088
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 562.1672
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 566.5606
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 566.7806
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 566.7806
# }, ];
#
# var series8 = chart.series.push(new am4charts.LineSeries());
# series8.dataFields.valueY = "Naira";
# series8.dataFields.dateX = "date";
# series8.strokeWidth = 3;
# series8.name = "YUAN/RENMINBI";
# series8.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series8.tensionX = 0.8;
# series8.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 61.843
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 61.9086
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 61.6298
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 61.4023
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 61.2909
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 61.303
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 61.3587
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 61.104
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 60.9875
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 60.5949
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 60.2786
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 60.2649
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 59.7695
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 60.7068
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 60.9033
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 60.9539
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 60.9988
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 61.0775
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 60.7156
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 60.7476
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 60.6988
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 60.6568
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 60.6866
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 60.4561
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 60.5056
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 60.3648
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 60.2608
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 59.8815
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 61.0421
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 60.6509
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 60.5052
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 60.1233
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 60.5051
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 60.3843
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 60.1027
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 60.9188
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 60.9325
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 60.8036
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 60.8424
# }, ];
#
#
# var series9 = chart.series.push(new am4charts.LineSeries());
# series9.dataFields.valueY = "Naira";
# series9.dataFields.dateX = "date";
# series9.strokeWidth = 3;
# series9.name = "RIYAL";
# series9.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series9.tensionX = 0.8;
# series9.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 114.017
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 114.0604
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 114.125
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 114.2424
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 114.3161
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 114.334
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 114.4297
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 114.4896
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 114.545
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 114.6665
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 114.8179
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 114.9136
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 114.854
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 115.1955
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 115.3032
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 115.3897
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 115.392
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 115.5715
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 115.8095
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 115.9085
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 116.0043
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 116.2453
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 116.3109
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 116.2681
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 116.3288
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 116.3873
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 116.4352
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 116.3888
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 116.5319
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 116.6844
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 116.7403
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 116.8228
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 116.9004
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 116.9802
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 117.0361
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 117.1247
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 117.2246
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 117.2407
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 117.3062
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 117.3784
# }, ];
#
# var series10 = chart.series.push(new am4charts.LineSeries());
# series10.dataFields.valueY = "Naira";
# series10.dataFields.dateX = "date";
# series10.strokeWidth = 3;
# series10.name = "SOUTH AFRICAN RAND";
# series10.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series10.tensionX = 0.8;
# series10.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 25.1216
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 25.1976
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 24.6028
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 24.4632
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 24.3004
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 24.2106
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 24.2219
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 24.3811
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 24.5378
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 24.1867
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 23.8794
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 24.1583
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 23.9214
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 24.0732
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 24.4237
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 23.3801
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 24.3588
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 24.1594
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 24.0475
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 23.9002
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 23.9002
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 23.8848
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 24.0721
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 24.1339
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 23.9851
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 23.9469
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 23.721
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 23.8719
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 23.696
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 24.3355
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 24.2422
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 24.2052
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 23.888
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 24.2379
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 24.281
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 23.8331
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 24.2011
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 24.6888
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 24.6872
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 24.7889
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 24.805
# }, ];
#
# var series11 = chart.series.push(new am4charts.LineSeries());
# series11.dataFields.valueY = "Naira";
# series11.dataFields.dateX = "date";
# series11.strokeWidth = 3;
# series11.name = "DANISH KRONA";
# series11.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series11.tensionX = 0.8;
# series11.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 58.5045
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 58.6776
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 57.7118
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 57.6581
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 57.5863
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 57.7412
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 57.9418
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 57.3691
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 57.2322
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 56.6007
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 55.9278
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 56.0165
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 55.6608
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 56.5629
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 57.6754
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 57.7771
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 57.5415
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 57.238
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 56.8943
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 56.845
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 57.1096
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 57.1876
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 57.7115
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 57.4653
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 57.6772
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 57.3267
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 57.8513
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 58.017
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 59.0154
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 59.0907
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 58.7106
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 58.579
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 58.6844
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 58.4823
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 57.6778
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 57.9305
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 59.0943
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 59.211
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 59.6331
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 59.0408
# }, ];
#
# var series12 = chart.series.push(new am4charts.LineSeries());
# series12.dataFields.valueY = "Naira";
# series12.dataFields.dateX = "date";
# series12.strokeWidth = 3;
# series12.name = "SDR";
# series12.tooltipText = "{name}: [bold]=N={valueY}[/]";
# series12.tensionX = 0.8;
# series12.data = [{
# "date": new Date(2022, 8, 12),
# "Naira": 558.0914
# }, {
# "date": new Date(2022, 8, 13),
# "Naira": 559.5113
# }, {
# "date": new Date(2022, 8, 14),
# "Naira": 560.7609
# }, {
# "date": new Date(2022, 8, 15),
# "Naira": 557.0776
# }, {
# "date": new Date(2022, 8, 16),
# "Naira": 556.3926
# }, {
# "date": new Date(2022, 8, 19),
# "Naira": 556.5189
# }, {
# "date": new Date(2022, 8, 20),
# "Naira": 556.9418
# }, {
# "date": new Date(2022, 8, 21),
# "Naira": 557.7695
# }, {
# "date": new Date(2022, 8, 22),
# "Naira": 556.1492
# }, {
# "date": new Date(2022, 8, 23),
# "Naira": 555.8023
# }, {
# "date": new Date(2022, 8, 26),
# "Naira": 552.7424
# }, {
# "date": new Date(2022, 8, 27),
# "Naira": 549.7457
# }, {
# "date": new Date(2022, 8, 28),
# "Naira": 550.1476
# }, {
# "date": new Date(2022, 8, 29),
# "Naira": 548.403
# }, {
# "date": new Date(2022, 9, 4),
# "Naira": 555.2347
# }, {
# "date": new Date(2022, 9, 5),
# "Naira": 558.9066
# }, {
# "date": new Date(2022, 9, 6),
# "Naira": 560.1438
# }, {
# "date": new Date(2022, 9, 7),
# "Naira": 559.6923
# }, {
# "date": new Date(2022, 9, 11),
# "Naira": 558.2338
# }, {
# "date": new Date(2022, 9, 12),
# "Naira": 556.1711
# }, {
# "date": new Date(2022, 9, 13),
# "Naira": 556.369
# }, {
# "date": new Date(2022, 9, 17),
# "Naira": 557.639
# }, {
# "date": new Date(2022, 9, 18),
# "Naira": 557.8487
# }, {
# "date": new Date(2022, 9, 19),
# "Naira": 558.9763
# }, {
# "date": new Date(2022, 9, 20),
# "Naira": 558.0567
# }, {
# "date": new Date(2022, 9, 21),
# "Naira": 558.6438
# }, {
# "date": new Date(2022, 9, 24),
# "Naira": 557.0353
# }, {
# "date": new Date(2022, 9, 25),
# "Naira": 559.0049
# }, {
# "date": new Date(2022, 9, 26),
# "Naira": 559.9685
# }, {
# "date": new Date(2022, 9, 27),
# "Naira": 560.403
# }, {
# "date": new Date(2022, 9, 28),
# "Naira": 566.292
# }, {
# "date": new Date(2022, 9, 31),
# "Naira": 564.3163
# }, {
# "date": new Date(2022, 10, 1),
# "Naira": 564.7662
# }, {
# "date": new Date(2022, 10, 2),
# "Naira": 565.2837
# }, {
# "date": new Date(2022, 10, 3),
# "Naira": 564.542
# }, {
# "date": new Date(2022, 10, 4),
# "Naira": 560.539
# }, {
# "date": new Date(2022, 10, 7),
# "Naira": 563.1736
# }, {
# "date": new Date(2022, 10, 8),
# "Naira": 567.5612
# }, {
# "date": new Date(2022, 10, 9),
# "Naira": 568.2196
# }, {
# "date": new Date(2022, 10, 10),
# "Naira": 569.5717
# }, ];
#
#
# /* Add legend */
# chart.legend = new am4charts.Legend();
#
# /* Create a cursor */
# chart.cursor = new am4charts.XYCursor();
#
# // Add scrollbar
# chart.scrollbarX = new am4charts.XYChartScrollbar();
# chart.scrollbarX.series.push(series);
# chart.scrollbarY = new am4core.Scrollbar();
#
#
#
# </script>
# </div></div>
# <div id="rightcol">
# <table background="#FBFDFC;" id="othertables" width="100%">
# <tr>
# <th align="left" style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; ">Facts : 1/1/1900</th>
# </tr>
# <tr>
# <td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px"><b>Agric Credit Guarantee Scheme</b>:The Agricultural Credit Guarantee Scheme (ACGS) was established in 1977, under the management of the Central Bank of Nigeria. The scheme was designed to encourage banks to increase lending to the agricultural sector by providing guarantee against inherent risks.</td>
# </tr>
# <tr>
# <td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;">See All: <a href="/HistoryFactsAll.asp?sign=1" target="_self">Facts </a>|<a href="/HistoryFactsAll.asp?sign=2" target="_self"> Events</a></td>
# </tr>
# </table>
# <br/>
# <table background="#FBFDFC;" id="othertables" width="100%">
# <tr align="left"><th align="left" style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;">Related Links</th></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/Rates/dutch.asp" target="_top">Foreign Exchange Dutch Auctions</a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/rates/macroindicators.asp" target="_top">Macroeconomic Indicators </a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/rates/wdas.asp" target="_top">Foreign Exchange Auction (WDAS)</a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/rates/govtsecurities.asp" target="_top"> Government Securities Summary</a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/rates/GovtSecuritiesDrillDown.asp" target="_top"> Government Secucurities Details</a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/rates/interbankrates.asp" target="_top">Interbank Rates</a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/documents/tedcirculars.asp" target="_top">Trade &amp; Exchange Circulars</a></td></tr><tr><td style="padding-left:10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px;"><a href="/rates/" target="_top"> Data &amp; Statistics </a></td></tr>
# </table>
# </div>
# <div id="footer">
# <div>
# <div id="longfooter">
# <div id="col1">
# <h2>Quick Links</h2>
# <ul style="list-style-type:square">
# <li><a href="/MonetaryPolicy/afcfta.asp" target="_top">AfCFTA</a></li>
# <li><a href="/documents/mpc.asp" target="_top">MPC Communique</a><br/></li>
# <li><a href="/CBNCommunity/" target="_top">CBN Community</a><br/></li>
# <li><a href="/museum/index.aspx" target="_top">Currency Museum</a><br/></li>
# <li><a href="/FOI/" target="_top">Freedom of Information Office</a><br/></li>
# <li><a href="/documents/BuyersGuide.asp" target="_top">Items and Publications For Sale</a><br/></li>
# <li><a href="/ITStandards/" target="_top">IT Standards Blueprint</a><br/></li>
# <li><a href="/News/newsarchives.asp" target="_top">News Archive</a><br/></li>
# <li><a href="/neff/" target="_top">Nigerian Electronic Fraud Forum</a><br/></li>
# <li><a href="/procurement/" target="_top">Procurement </a><br/></li>
# <li><a href="/sisorgs.asp" target="_top">Related Institutions</a><br/></li>
# <li><a href="/Audios/cbnact/playcbnact.asp" target="_top">CBN 2007 Act - Audio Version</a><br/></li>
# <li><a href="http://statistics.cbn.gov.ng/cbn-onlinestats/" target="_top">Statistics Database</a><br/></li>
# <li><a href="/Out/2021/CCD/ISMSpolicy2021.pdf" target="_top">Our Information Security Policy</a><br/></li>
# <li><a href="https://www.sgs.com/en/connectivity-and-products/government-and-trade-facilitation/cross-border-einvoicing/nigeria-cross-border-einvoicing" target="_top">e-Invoicing App</a><br/></li>
# </ul>
# </div>
# <div id="col2">
# <h2>Contact Us</h2>
# <p>Phone: +234 700 225 5226</p>
# <p>Toll free line: +234 800 225 5226</p>
# <p>Email: <a href="/cdn-cgi/l/email-protection#e1828e8f9580829582838fa182838fcf868e97cf8f86" style="color:white"><span class="__cf_email__" data-cfemail="accfc3c2d8cdcfd8cfcec2eccfcec282cbc3da82c2cb">[email protected]</span></a></p>
# <p> Complaints Against Financial Institutions:<br/>
# <a href="/cdn-cgi/l/email-protection#c5a6b5a185a6a7abeba2aab3ebaba2" style="color:white"><span class="__cf_email__" data-cfemail="dfbcafbb9fbcbdb1f1b8b0a9f1b1b8">[email protected]</span></a></p>
# <p>Authorized Dealer Enquires:<br/>
# +234 9 462 37804, +234 9 462 37802</p>
# <p>Commercial Agricultural Credit Scheme (CACS):	<br/>
# +234 9 46237602</p>
# <p>
# Ethics &amp; Anti-Corruption Helpline:<br/>
# +234 9 462 39246
# +234 9 462 36000
# <a href="/cdn-cgi/l/email-protection#4d283925242e3e222b2b242e280d2e2f23632a223b63232a" style="color:white"><span class="__cf_email__" data-cfemail="ee8b9a86878d9d818888878d8bae8d8c80c0898198c08089">[email protected]</span></a>
# <a href="/cdn-cgi/l/email-protection#ef8e819b868c809d9d9a9f9b8680819a81869baf8c8d81c1888099c18188" style="color:white"><span class="__cf_email__" data-cfemail="9afbf4eef3f9f5e8e8efeaeef3f5f4eff4f3eedaf9f8f4b4fdf5ecb4f4fd">[email protected]</span></a>
# </p>
# <p>Forex Helpdesk:	<br/>
# +234 9 462 37827
# +234 9 462 37831</p>
# </div>
# <div id="col3">
# <h2>Address</h2>
# <address class="vcard">
# <div class="fn org">Central Bank of Nigeria</div>
# <div class="street-address">Plot 33,</div>
# <div class="adr">
# Abubakar Tafawa Balewa Way
# <br/>
# Central Business District,
# <br/>
# Cadastral Zone,
# </div>
# <span class="locality">Abuja,</span>
# <br/>
# <span class="region">Federal Capital Territory,</span>
# <br/>
# <span class="country">Nigeria</span>
# <br/>
# </address>
#  P.M.B. 0187,
# <br/>
# Garki Abuja.
# <br/>
# Nigeria
# <br/>
# <p><font style="font-style:italic">We are open for business Monday through Friday except on national holidays. Official visiting days are Tuesdays and Thursdays by appointment only. Our working hours are from 8:00a.m. - 4:00p.m.</font></p><br/>
# <br/><a href="/legal.asp" style="color:white">Legal Disclaimer</a>
# <br/><a href="/Out/2021/CCD/PRIVACY NOTICE for CBN External Stakeholders 05.pdf" style="color:white">Privacy Notice</a>
# </div>
# <div id="col4">
# <h2>Follow Us</h2>
# <ul>
# <li><a href="https://twitter.com/cenbank"><img src="/images/Bullets/Twitter-icon.png"/>Twitter</a></li>
# <li><a href="https://www.facebook.com/cenbankng"><img src="/images/Bullets/FaceBook-icon.png"/>Facebook</a></li>
# <li><a href="https://www.flickr.com/photos/78609336@N02/"><img src="/images/Bullets/flickr_optimized.jpg"/>Flickr</a></li>
# <li><a href="https://www.youtube.com/cenbank"><img src="/images/Bullets/YouTube-icon.png"/>YouTube</a></li>
# <li><a href="https://www.instagram.com/centralbankng"><img src="/images/Bullets/instagram_small.png"/>Instagram</a></li>
# </ul>
# <h2>Subscribe to our RSS Feeds</h2>
# <ul>
# <li><a href="/RSS/createrssfromdb.asp"><img src="/images/Bullets/icon_rss.gif"/>News</a></li>
# <li><a href="/RSS/createrssfromdb.asp?item=Circulars" target="_self"><img src="/images/Bullets/icon_rss.gif"/>Circulars</a></li>
# <li><a href="/RSS/createrssfromdb.asp?item=Publications" target="_self"><img src="/images/Bullets/icon_rss.gif"/>Publications</a></li>
# <li><a href="/RSS/createrssfromdb.asp?item=Speeches" target="_self"><img src="/images/Bullets/icon_rss.gif"/>Speeches</a></li>
# </ul>
# </div>
# </div>
# <div id="cookiePopup" style="display: none;">
# <p align="center">For all visitors to its website, the CBN requires the Stakeholder to read and agree to the terms of the
# <a href="/Out/2021/CCD/PRIVACY%20NOTICE%20for%20CBN%20External%20Stakeholders%2005.pdf" target="_blank"><strong>Privacy/Cookie Notice</strong></a> on its website. <button id="acceptCookie">Agree</button>
# </p>
# <style>
# #cookiePopup {
#   position: fixed;
#   bottom: 0px;
#   left:0%;
#   right:0%;
#   width: 100%;
#   padding: 5px 14px;
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   background-color: #dfe6e4;
#   border-radius: 5px;
#   box-shadow: 0 0 2px 1px rgba(0, 0, 0, 0.2);
#   z-index: 5;
# }
# #acceptCookie {
#   height: 20px;
#   background-color: #777;
#   border: #ffffff;
#   color: white;
#   border-radius: 2px;
#   padding: 0.2em 1.5em;
#
# }
#         </style>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="text/javascript">
#             // set cookie according to you
#             var cookieName = "CBNPrivacyNotice";
#             var cookieValue = "CBN Privacy Notice";
#             var cookieExpireDays = 100000000000000;
#
#             // when users click accept button
#             let acceptCookie = document.getElementById("acceptCookie");
#             acceptCookie.onclick = function () {
#                 createCookie(cookieName, cookieValue, cookieExpireDays);
#             }
#
#             // function to set cookie in web browser
#             let createCookie = function (cookieName, cookieValue, cookieExpireDays) {
#                 let currentDate = new Date();
#                 currentDate.setTime(currentDate.getTime() + (cookieExpireDays * 24 * 60 * 60 * 1000));
#                 let expires = "expires=" + currentDate.toGMTString();
#                 document.cookie = cookieName + "=" + cookieValue + ";" + expires + ";path=/";
#                 if (document.cookie) {
#                     document.getElementById("cookiePopup").style.display = "none";
#                 } else {
#                     alert("Unable to set cookie. Please allow all cookies site from cookie setting of your browser");
#                 }
#
#             }
#
#             // get cookie from the web browser
#             let getCookie = function (cookieName) {
#                 let name = cookieName + "=";
#                 let decodedCookie = decodeURIComponent(document.cookie);
#                 let ca = decodedCookie.split(';');
#                 for (let i = 0; i < ca.length; i++) {
#                     let c = ca[i];
#                     while (c.charAt(0) == ' ') {
#                         c = c.substring(1);
#                     }
#                     if (c.indexOf(name) == 0) {
#                         return c.substring(name.length, c.length);
#                     }
#                 }
#                 return "";
#             }
#             // check cookie is set or not
#             let checkCookie = function () {
#                 let check = getCookie(cookieName);
#                 if (check == "") {
#                     document.getElementById("cookiePopup").style.display = "block";
#                 } else {
#
#                     document.getElementById("cookiePopup").style.display = "none";
#                 }
#             }
#             checkCookie();
#         </script>
# </div>
# <script src="scripts/chat.js"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-24414924-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# </div></div>
# </div>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"76868ad19bf5d424","token":"4d95a0b05d714a0d8d9b92d836b3c205","version":"2022.11.0","si":100}' defer="" integrity="sha512-0ahDYl866UMhKuYcW078ScMalXqtFJggm7TmlUtp0UlD4eQk0Ixfnm5ykXKvGJNFjLMoortdseTfsRT8oCfgGA==" src="https://static.cloudflareinsights.com/beacon.min.js/vaafb692b2aea4879b33c060e79fe94621666317369993"></script>
# </body>
# </html>

# %%
'tr' 
'td' 
'th' - table header
# Out:
#   Input In [32]
#     'th' - table header
#                  ^
# SyntaxError: invalid syntax

# %%
for rows in content.find_all('tr')[1]:
    print(rows.text)
# Out:
# Date
# Currency
# Buying(NGN)
# Central(NGN)
# Selling(NGN)

# %%
list_row = []
for header in content.find_all('tr'):
    list_row.append(header.text)
    
df = pd.DataFrame(columns= list_row)
row_team = []
tr = content.find_all('tr')
list_of_rows = []
for table_row in range(1,len(tr)):
    list_for_each_row = []
    tr_small = tr[table_row]
    for row in tr_small:
        list_for_each_row.append(row.text)
        list_of_rows.append(list_for_each_row)
        
for i in list_of_rows:
    df.loc[len(df)] = i
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 16>()
#      14         list_of_rows.append(list_for_each_row)
#      16 for i in list_of_rows:
# ---> 17     df.loc[len(df)] = i
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1682, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1679     indexer, missing = convert_missing_indexer(indexer)
#    1681     if missing:
# -> 1682         self._setitem_with_indexer_missing(indexer, value)
#    1683         return
#    1685 # align and set the values
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1998, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    1995     if is_list_like_indexer(value):
#    1996         # must have conforming columns
#    1997         if len(value) != len(self.obj.columns):
# -> 1998             raise ValueError("cannot set a row with mismatched columns")
#    2000     value = Series(value, index=self.obj.columns, name=indexer)
#    2002 if not len(self.obj):
#    2003     # We will ignore the existing dtypes instead of using
#    2004     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %%
df
# Out:
# Empty DataFrame
# Columns: [
# Home | About Us | FAQs | RSS | Contact Us | Sitemap | Careers | Educational | Freedom of Information
#
#
#
#
#
#
#
#
#
#
# , DateCurrencyBuying(NGN)Central(NGN)Selling(NGN), DateCurrencyBuying(NGN)Central(NGN)Selling(NGN),
# Facts : 1/7/1959
# ,
# Evolution of Departments:At inception, the organisational structure of the CBN was understandably simple consisting of two departments, namely, the General Manager's and the Secretary's Departments, with the appropriate division of labour as then percieved. The General Manager's Department was responsible for all the Department banking, currency issues, debt management and other operational functions of the bank while the Secretary's Department handled the administrative and staff matters, carried out some research into the economic and financial conditions, and collected and analysed relevant statistics for policy formulation.
# ,
# See All: Facts | Events
# , Related Links, Foreign Exchange Dutch Auctions, Macroeconomic Indicators , Foreign Exchange Auction (WDAS),  Government Securities Summary,  Government Secucurities Details, Interbank Rates, Trade & Exchange Circulars,  Data & Statistics ]
# Index: []

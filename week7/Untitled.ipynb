# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/STUTERN/Desktop/Intermediate_project/week7/nigeria_inflation_rate.csv")
df
# Out:
#      Unnamed: 0  Year  Nigeria      EU     USA   World
# 0             0  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 1             1  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 2             2  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 3             3  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 4             4  2021  16.95 %  2.55 %  4.70 %  3.42 %
# ..          ...   ...      ...     ...     ...     ...
# 305         305  1960   5.44 %  1.74 %  1.46 %     NaN
# 306         306  1960   5.44 %  1.74 %  1.46 %     NaN
# 307         307  1960   5.44 %  1.74 %  1.46 %     NaN
# 308         308  1960   5.44 %  1.74 %  1.46 %     NaN
# 309         309  1960   5.44 %  1.74 %  1.46 %     NaN
#
# [310 rows x 6 columns]

# %%
# renaming the column name to remove Ø sign
df.rename(columns= {'EU': 'EU',
                   'USA': 'USA',
                  'World': 'World'}, inplace=True)

# %%
df
# Out:
#      Unnamed: 0  Year  Nigeria      EU     USA   World
# 0             0  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 1             1  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 2             2  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 3             3  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 4             4  2021  16.95 %  2.55 %  4.70 %  3.42 %
# ..          ...   ...      ...     ...     ...     ...
# 305         305  1960   5.44 %  1.74 %  1.46 %     NaN
# 306         306  1960   5.44 %  1.74 %  1.46 %     NaN
# 307         307  1960   5.44 %  1.74 %  1.46 %     NaN
# 308         308  1960   5.44 %  1.74 %  1.46 %     NaN
# 309         309  1960   5.44 %  1.74 %  1.46 %     NaN
#
# [310 rows x 6 columns]

# %%
df.World.value_counts().head()
# Out:
# 2.19 %    10
# 4.82 %    10
# 3.42 %     5
# 7.00 %     5
# 6.55 %     5
# Name: World, dtype: int64

# %%
df.World
# Out:
# 0      3.42 %
# 1      3.42 %
# 2      3.42 %
# 3      3.42 %
# 4      3.42 %
#         ...
# 305       NaN
# 306       NaN
# 307       NaN
# 308       NaN
# 309       NaN
# Name: World, Length: 310, dtype: object

# %%
df.World.value_counts().head()
# Out:
# 2.19 %    10
# 4.82 %    10
# 3.42 %     5
# 7.00 %     5
# 6.55 %     5
# Name: World, dtype: int64

# %%
df["World"].fillna("2.19 %", inplace = True)

# %%
df.tail()
# Out:
#      Unnamed: 0  Year Nigeria      EU     USA   World
# 305         305  1960  5.44 %  1.74 %  1.46 %  2.19 %
# 306         306  1960  5.44 %  1.74 %  1.46 %  2.19 %
# 307         307  1960  5.44 %  1.74 %  1.46 %  2.19 %
# 308         308  1960  5.44 %  1.74 %  1.46 %  2.19 %
# 309         309  1960  5.44 %  1.74 %  1.46 %  2.19 %

# %%
# df[['Nigeria','EU','USA','World']] = pd.to_numeric(df['Nigeria','EU','USA','World'].astype(str).str[:-1])

# %%
df['Nigeria'] = pd.to_numeric(df['Nigeria'].astype(str).str[:-1])

# %%
# cols = ['EU','USA','World']
# # df[cols] = df[cols].apply(pd.to_numeric)
# df[cols] = pd.to_numeric(df[cols].astype(str).str[:-1])

# %%
df
# Out:
#      Unnamed: 0  Year  Nigeria      EU     USA   World
# 0             0  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 1             1  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 2             2  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 3             3  2021  16.95 %  2.55 %  4.70 %  3.42 %
# 4             4  2021  16.95 %  2.55 %  4.70 %  3.42 %
# ..          ...   ...      ...     ...     ...     ...
# 305         305  1960   5.44 %  1.74 %  1.46 %  2.19 %
# 306         306  1960   5.44 %  1.74 %  1.46 %  2.19 %
# 307         307  1960   5.44 %  1.74 %  1.46 %  2.19 %
# 308         308  1960   5.44 %  1.74 %  1.46 %  2.19 %
# 309         309  1960   5.44 %  1.74 %  1.46 %  2.19 %
#
# [310 rows x 6 columns]
